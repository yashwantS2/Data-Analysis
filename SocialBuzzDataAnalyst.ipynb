# %%
import pandas as pd

# %%
ReactionTypeData = pd.read_csv('/Users/yashwantsingh/Documents/Accenture/Dataset Without Preprocced/ReactionTypes.csv')
reactionData = pd.read_csv('/Users/yashwantsingh/Documents/Accenture/Dataset Without Preprocced/Reactions.csv')
contentData  = pd.read_csv('/Users/yashwantsingh/Documents/Accenture/Dataset Without Preprocced/Content.csv')

# %% [markdown]
# ### ReactionTypeData Preprocessing

# %%
ReactionTypeData.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
ReactionTypeData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   Type        16 non-null     object
#  2   Sentiment   16 non-null     object
#  3   Score       16 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 644.0+ bytes

# %% [markdown]
# ## contentData Preprocessing

# %%
contentData.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
contentData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
final_contentData =contentData.drop(columns=['URL', 'User ID'])

# %%
final_contentData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   Type        1000 non-null   object
#  3   Category    1000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# ## reactionData Preprocessing

# %%
reactionData.head()
# Out:
#    Unnamed: 0                            Content ID     Type        Datetime
# 0         NaN                                   NaN      NaN             NaN
# 1         1.0  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust   07/11/20 9:43
# 2         2.0  97522e57-d9ab-4bd6-97bf-c24d952602d2  dislike  17/06/21 12:22
# 3         3.0  97522e57-d9ab-4bd6-97bf-c24d952602d2   scared   18/04/21 5:13
# 4         4.0  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust  06/01/21 19:13

# %%
reactionData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24573 non-null  float64
#  1   Content ID  24573 non-null  object
#  2   Type        24573 non-null  object
#  3   Datetime    24573 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 798.7+ KB

# %%
reactionData = reactionData.dropna()

# %%
reactionData
# Out:
#        Unnamed: 0                            Content ID        Type  \
# 1             1.0  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2             2.0  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3             3.0  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4             4.0  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 5             5.0  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
# ...           ...                                   ...         ...
# 25548     25548.0  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike
# 25549     25549.0  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued
# 25550     25550.0  75d6b589-7fae-4a6d-b0d0-752845150e56  interested
# 25551     25551.0  75d6b589-7fae-4a6d-b0d0-752845150e56     worried
# 25552     25552.0  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish
#
#              Datetime
# 1       07/11/20 9:43
# 2      17/06/21 12:22
# 3       18/04/21 5:13
# 4      06/01/21 19:13
# 5      23/08/20 12:25
# ...

# %%
distn_val =reactionData['Type'].unique()

# %%
distn_val
# Out:
# array(['disgust', 'dislike', 'scared', 'interested', 'peeking', 'cherish',
#        'hate', 'love', 'indifferent', 'super love', 'intrigued',
#        'worried', 'like', 'heart', 'want', 'adore'], dtype=object)

# %% [markdown]
# # Table Merging

# %%
reactions_with_types = pd.merge(reactionData, ReactionTypeData, on='Type', how='left')

# %%
reactions_with_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24573 entries, 0 to 24572
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0_x  24573 non-null  float64
#  1   Content ID    24573 non-null  object
#  2   Type          24573 non-null  object
#  3   Datetime      24573 non-null  object
#  4   Unnamed: 0_y  24573 non-null  int64
#  5   Sentiment     24573 non-null  object
#  6   Score         24573 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.3+ MB

# %%
final_data = pd.merge(reactions_with_types, final_contentData, on='Content ID', how='left')

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24573 entries, 0 to 24572
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0_x  24573 non-null  float64
#  1   Content ID    24573 non-null  object
#  2   Type_x        24573 non-null  object
#  3   Datetime      24573 non-null  object
#  4   Unnamed: 0_y  24573 non-null  int64
#  5   Sentiment     24573 non-null  object
#  6   Score         24573 non-null  int64
#  7   Unnamed: 0    24573 non-null  int64
#  8   Type_y        24573 non-null  object
#  9   Category      24573 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.9+ MB

# %%
final_data.sample(10)
# Out:
#        Unnamed: 0_x                            Content ID       Type_x  \
# 14421       14989.0  24231380-c9a7-4b07-bd51-c9bd5c49cb7c  indifferent
# 8242         8563.0  eec5dae8-e4d0-4b15-80a9-ac55352cb5ca         want
# 1138         1183.0  220d9dc1-f8a5-422d-b200-3819f3b89b2b      dislike
# 9566         9938.0  b6ecb09e-a706-4589-bb75-70cb1cc590eb      disgust
# 15580       16199.0  0c6e8e2a-7692-4490-b545-f76b0d06697a         want
# 22958       23875.0  edea43f3-1541-4e42-8419-d1cdf749025c         like
# 17756       18467.0  79818849-98f9-4b6b-9be8-4ed4c1ad59a5        adore
# 5757         5983.0  b1c49557-0623-4fb2-8f22-1453286fedad       scared
# 4024         4179.0  7bb8c7ec-8d65-43e8-a9fb-ac01936b18cc   interested
# 7982         8293.0  9ee8836d-af4b-46ad-8869-4e0b1dedff7d        adore
#
#              Datetime  Unnamed: 0_y Sentiment  Score  Unnamed: 0 Type_y  \
# 14421  09/03/21 23:53             5   neutral     20         575  photo
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24573 entries, 0 to 24572
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0_x  24573 non-null  float64
#  1   Content ID    24573 non-null  object
#  2   Type_x        24573 non-null  object
#  3   Datetime      24573 non-null  object
#  4   Unnamed: 0_y  24573 non-null  int64
#  5   Sentiment     24573 non-null  object
#  6   Score         24573 non-null  int64
#  7   Unnamed: 0    24573 non-null  int64
#  8   Type_y        24573 non-null  object
#  9   Category      24573 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.9+ MB

# %%
final_data = final_data.rename(columns={'Type_x': 'Reaction type'})

# %%
final_data.sample(20)
# Out:
#        Unnamed: 0_x                            Content ID Reaction type  \
# 10909       11343.0  e409d5be-a02d-4688-9869-eb940fe1e133         adore
# 21335       22191.0  3c6354b3-7e8a-4d8c-bb80-33f17c17bd32          hate
# 10402       10813.0  9108109e-c521-4528-9d90-4c804cbb866d         heart
# 939           977.0  457301ee-3e87-40d8-8b82-ea4e1fa90e39     intrigued
# 21222       22073.0  b3b384bf-3a17-4ccb-ba86-583dede8fe3c       worried
# 12653       13158.0  888660b0-7dd8-4983-858a-101cd03d392b       dislike
# 7531         7824.0  11b96207-c1c5-4083-948d-2942684aae0d         heart
# 8262         8584.0  3ce1063a-2277-4285-97b0-9bd53a941cd7     intrigued
# 15088       15685.0  1d8fbfdc-3c0f-4fbf-ac50-f812ce9db36e   indifferent
# 19282       20059.0  4dd4da35-453e-466d-95ca-b1a7710fac1f    super love
# 23544       24482.0  5dc325aa-d5d1-4552-9997-cd25b7608be9    super love
# 11310       11758.0  e0c5ae74-b379-4d34-a7ae-824daea8d682     intrigued
# ...

# %%
final_data = final_data.rename(columns={'Type_y': 'Content type'})

# %%
final_data.head()
# Out:
#    Unnamed: 0_x                            Content ID Reaction type  \
# 0           1.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1           2.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2           3.0  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3           4.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4           5.0  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
#
#          Datetime  Unnamed: 0_y Sentiment  Score  Unnamed: 0 Content type  \
# 0   07/11/20 9:43             2  negative      0           0        photo
# 1  17/06/21 12:22            11  negative     10           0        photo
# 2   18/04/21 5:13            14  negative     15           0        photo
# 3  06/01/21 19:13             2  negative      0           0        photo
# 4  23/08/20 12:25             4  positive     30           0        photo
#
#    Category
# 0  Studying
# 1  Studying
# 2  Studying
# 3  Studying
# 4  Studying

# %%
final_data = final_data.drop(columns=['','Unnamed: 0_y', 'Unnamed: 0'])

# %%
final_data.head()
# Out:
#    Unnamed: 0_x                            Content ID Reaction type  \
# 0           1.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1           2.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2           3.0  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3           4.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4           5.0  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
#
#          Datetime Sentiment  Score Content type  Category
# 0   07/11/20 9:43  negative      0        photo  Studying
# 1  17/06/21 12:22  negative     10        photo  Studying
# 2   18/04/21 5:13  negative     15        photo  Studying
# 3  06/01/21 19:13  negative      0        photo  Studying
# 4  23/08/20 12:25  positive     30        photo  Studying

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24573 entries, 0 to 24572
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0_x   24573 non-null  float64
#  1   Content ID     24573 non-null  object
#  2   Reaction type  24573 non-null  object
#  3   Datetime       24573 non-null  object
#  4   Sentiment      24573 non-null  object
#  5   Score          24573 non-null  int64
#  6   Content type   24573 non-null  object
#  7   Category       24573 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
final_data = final_data.drop(columns=['Unnamed: 0_x'])

# %%
final_data.head()
# Out:
#                              Content ID Reaction type        Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust   07/11/20 9:43
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  17/06/21 12:22
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared   18/04/21 5:13
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  06/01/21 19:13
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  23/08/20 12:25
#
#   Sentiment  Score Content type  Category
# 0  negative      0        photo  Studying
# 1  negative     10        photo  Studying
# 2  negative     15        photo  Studying
# 3  negative      0        photo  Studying
# 4  positive     30        photo  Studying

# %%
#Table Processed

# %% [markdown]
# # Exporting Final Table

# %%
final_data.to_excel('/Users/yashwantsingh/Documents/Final_Combined_Data.xlsx', index=False)
